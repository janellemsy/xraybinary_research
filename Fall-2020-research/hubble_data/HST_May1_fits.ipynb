# %%
import matplotlib.pyplot as plt
import pyspeckit 
import numpy as np

# %%
#May 1
data3 = np.loadtxt('le6g01010_x1dsum_May1.txt')
x3 = data3[:,0]
y3 = data3[:,1]

#plotting May 1
plt.figure(figsize=(12,8))
plt.subplot(2,2,3)
plt.plot(x3, y3,color='b')
plt.xlim(1100,2550)
plt.ylim(-1.0e-14,3e-14)

#axes & title
plt.title('May 1', y=1.05)
plt.xlabel('Wavelength \u03BB (\u212B)')
plt.ylabel('$F_\u03BB$ (erg s$^{-1}$ cm$^{-2}$ \u212B$^{-1}$)')
plt.grid()


plt.show()

# %%
#GAUSSIAN FITTING
#geochromal airglow line (ignore for now)~

# plotting data

data = 'le6g01010_x1dsum_May1.txt'
sp = pyspeckit.Spectrum(data)

#limits and axes
sp.plotter(xmin = 1290, xmax = 1320,ymax = 1e-14, color = 'k')
plt.title('May 1 Guassian #1 Fit')
sp.plotter.axis.set_xlabel(r'Wavelength $(\AA)$')
sp.plotter.axis.set_ylabel(r'Flux ($\mathrm{erg/s/cm^2/\AA})$')
plt.grid()
sp.plotter.refresh()

#Fitting with automatic guesses
sp.specfit(fittype='gaussian', annotate = False)

print(sp.specfit.parinfo)
# Out:
# Warning: Invalid xtype in text header - this may mean no text header was available.  X-axis units will be pixels unless you set them manually (e.g., sp.xarr=SpectroscopicAxis(sp.xarr.value, unit='angstroms')
# Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
# Warning: 'partition' will ignore the 'mask' of the MaskedArray.
# INFO: Renormalizing data by factor 3.144409e-18 to improve fitting procedure [pyspeckit.spectrum.fitters]
# Param #0   AMPLITUDE0 =  3.38506e-15 +/-     6.55344e-17
# Param #1       SHIFT0 =      1303.88 +/-       0.0615997
# Param #2       WIDTH0 =      3.70085 +/-       0.0515414   Range:   [0,inf)

# %%
import matplotlib.pyplot as plt
import pyspeckit 
import numpy as np

#GAUSSIAN FITTING

# plotting data
data = 'le6g01010_x1dsum_May1.txt'
sp = pyspeckit.Spectrum(data)

#limits and axes
sp.plotter(xmin = 1620, xmax = 1660,ymax = 1e-14, color = 'k')
plt.title('May 1 Guassian #2 Fit')
sp.plotter.axis.set_xlabel(r'Wavelength $(\AA)$')
sp.plotter.axis.set_ylabel(r'Flux ($\mathrm{erg/s/cm^2/\AA})$')
plt.grid()
sp.plotter.refresh()

#Fitting with automatic guesses
sp.specfit(fittype='gaussian', annotate = False)

print(sp.specfit.parinfo)
# Out:
# Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
# Warning: 'partition' will ignore the 'mask' of the MaskedArray.
# INFO: Renormalizing data by factor 3.144409e-18 to improve fitting procedure [pyspeckit.spectrum.fitters]
# Param #0   AMPLITUDE0 =   7.6258e-16 +/-     8.24279e-17
# Param #1       SHIFT0 =      1640.85 +/-        0.410295
# Param #2       WIDTH0 =      3.65013 +/-        0.403718   Range:   [0,inf)

# %%
import matplotlib.pyplot as plt
import pyspeckit 
import numpy as np

#GAUSSIAN FITTING

# plotting data
data = 'le6g01010_x1dsum_May1.txt'
sp = pyspeckit.Spectrum(data)

#limits and axes
sp.plotter(xmin = 1780, xmax = 1810,ymax = 1.5e-15, color = 'k')
plt.title('May 1 Guassian #3 Fit')
sp.plotter.axis.set_xlabel(r'Wavelength $(\AA)$')
sp.plotter.axis.set_ylabel(r'Flux ($\mathrm{erg/s/cm^2/\AA})$')
plt.grid()
sp.plotter.refresh()

#Fitting with automatic guesses
sp.specfit(fittype='gaussian', annotate = False)

print(sp.specfit.parinfo)
# Out:
# Warning: Invalid xtype in text header - this may mean no text header was available.  X-axis units will be pixels unless you set them manually (e.g., sp.xarr=SpectroscopicAxis(sp.xarr.value, unit='angstroms')
# Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
# Warning: 'partition' will ignore the 'mask' of the MaskedArray.
# INFO: Renormalizing data by factor 3.144409e-18 to improve fitting procedure [pyspeckit.spectrum.fitters]
# Param #0   AMPLITUDE0 =   3.8799e-16 +/-     5.89869e-16
# Param #1       SHIFT0 =      1797.93 +/-        0.250154
# Param #2       WIDTH0 =     0.148305 +/-        0.249908   Range:   [0,inf)
