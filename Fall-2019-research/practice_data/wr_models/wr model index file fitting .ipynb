# %%
# %matplotlib inline
import numpy as np
from numpy import *
import matplotlib.pyplot as plt
import sherpa.ui as ui
from astropy.io import fits

#Data using sherpa
ui.load_data('lmc-wne_09-14_sed.txt')
print(ui.get_data())
x2 = ui.get_data().x
y2 = ui.get_data().y
wavelength = 10**x2
y2linear = 10**y2
flux2 = 2.5e-11*y2linear

(ui.get_data().x)
(ui.get_data().y)

#plotting with sherpa
ui.load_arrays(1, wavelength, flux2)
print('y-mean:')
print(ui.get_data().y.mean())
print('y range:')
print(np.ptp(ui.get_data().y))

#rescaling data
d1 = ui.get_data()
d1.y *= 1e16

#setting errors
d1.staterror == None
True
ui.set_staterror(0.02, fractional=True)
d1.staterror == None
False

#filtering data and plotting
ui.notice(900, 2391)
ui.plot_data()

#template model fit
ui.load_template_model("wr_model","template_models.txt")
ui.set_model(wr_model)

#disabling template interpolator
ui.load_template_model("wr_model","template_models.txt", template_interpolator_name=None)

from sherpa.utils import neville, nearest_interp, linear_interp
from sherpa.models import KNNInterpolator

ui.load_template_interpolator("KNN",KNNInterpolator)
ui.load_template_model("wr_model","template_models.txt", template_interpolator_name="KNN")
# Out:
# WARNING: imaging routines will not be available,
# failed to import sherpa.image.ds9_backend due to
# 'RuntimeErr: DS9Win unusable: Could not find ds9 on your PATH'
# name      = lmc-wne_09-14_sed.txt
# x         = Float64[1795]
# y         = Float64[1795]
# staterror = None
# syserror  = None
# y-mean:
# 5.203253808074407e-16
# y range:
# 5.827965989457039e-15

# %%
#parameter values
print(wr_model.parvals)

#changing optimization method from levmar to gridsearch
ui.set_method("gridsearch")
ui.set_method_opt('sequence', wr_model.parvals)

#plotting fit

ui.fit()
ui.plot_fit_resid()
# Out:
# [[112.2   7.9]
#  [ 89.1   4. ]
#  [ 79.4  50. ]
#  [ 63.1   5. ]
#  [ 63.1  32. ]
#  [ 50.1   2. ]]
# Dataset               = 1
# Method                = gridsearch
# Statistic             = chi2
# Initial fit statistic = 4.0539e+17
# Final fit statistic   = 2.73516e+10 at function evaluation 7
# Data points           = 275
# Degrees of freedom    = 273
# Probability [Q-value] = 0
# Reduced statistic     = 1.00189e+08
# Change in statistic   = 4.0539e+17
#    wr_model.temp   50.1
#    wr_model.radius   2
# WARNING: parameter value wr_model.temp is at its minimum boundary 50.1
# WARNING: parameter value wr_model.radius is at its minimum boundary 2.0
