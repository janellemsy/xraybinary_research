# %%
import matplotlib.pyplot as plt
from astropy.io import fits

plt.figure(figsize=(10,6))
x1ddata = fits.getdata('lbji01010_x1dsum.fits')

# select segment A or segment B data
x1d_fuva = x1ddata['segment'] == 'FUVA'
x1d_fuvb = x1ddata['segment'] == 'FUVB'

# select the wavelength and flux columns for each segment
wave_fuva = x1ddata[x1d_fuva]['wavelength'].flatten()
flux_fuva = x1ddata[x1d_fuva]['flux'].flatten()
wave_fuvb = x1ddata[x1d_fuvb]['wavelength'].flatten()
flux_fuvb = x1ddata[x1d_fuvb]['flux'].flatten()

# plot segment A
plt.plot(wave_fuva, flux_fuva)

#making plot pretty
plt.title('lbji01010_x1dsum.fits segment a')
plt.xlabel('Wavelength \u03BB (\u212B)')
plt.ylabel('Flux (erg s$^{-1}$ cm$^{-2}$ \u212B$^{-1}$)')

plt.xlim(1100,2550)
plt.ylim(-1.5e-14,3e-14)

plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np

plt.figure(figsize=(10,6))
x1ddata = fits.getdata('lbji01010_x1dsum.fits')

# select segment A or segment B data
x1d_fuva = x1ddata['segment'] == 'FUVA'
x1d_fuvb = x1ddata['segment'] == 'FUVB'

# select the wavelength and flux columns for each segment
wave_fuva = x1ddata[x1d_fuva]['wavelength'].flatten()
flux_fuva = x1ddata[x1d_fuva]['flux'].flatten()
wave_fuvb = x1ddata[x1d_fuvb]['wavelength'].flatten()
flux_fuvb = x1ddata[x1d_fuvb]['flux'].flatten()

# plot segment b
plt.plot(wave_fuvb, flux_fuvb)

#making plot pretty
plt.title('lbji01010_x1dsum.fits segment b')
plt.xlabel('Wavelength \u03BB (\u212B)')
plt.ylabel('Flux (erg s$^{-1}$ cm$^{-2}$ \u212B$^{-1}$)')

plt.xlim(900,1300)
plt.ylim(-0.3e-14,1.5e-14)
plt.xticks(np.arange(900, 1300, 50))

plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
from astropy.io import fits

x1ddata = fits.getdata('lbji01noq_x1d.fits')

# select segment A or segment B data
x1d_fuva = x1ddata['segment'] == 'FUVA'
x1d_fuvb = x1ddata['segment'] == 'FUVB'

# select the wavelength and flux columns for each segment
wave_fuva = x1ddata[x1d_fuva]['wavelength'].flatten()
flux_fuva = x1ddata[x1d_fuva]['flux'].flatten()
wave_fuvb = x1ddata[x1d_fuvb]['wavelength'].flatten()
flux_fuvb = x1ddata[x1d_fuvb]['flux'].flatten()

# plot segment A
plt.plot(wave_fuva, flux_fuva)
plt.xlabel('Wavelength (\u212B)')
plt.xlim(1200,2400)
plt.ylabel('Flux')
plt.ylim(-1.0e-14,2.5e-14)
plt.grid()
plt.show()

# %%
x1ddata = fits.getdata('lbji01nsq_x1d.fits')
# select segment A or segment B data
x1d_fuva = x1ddata['segment'] == 'FUVA'
x1d_fuvb = x1ddata['segment'] == 'FUVB'
# select the wavelength and flux columns for each segment
wave_fuva = x1ddata[x1d_fuva]['wavelength'].flatten()
flux_fuva = x1ddata[x1d_fuva]['flux'].flatten()
wave_fuvb = x1ddata[x1d_fuvb]['wavelength'].flatten()
flux_fuvb = x1ddata[x1d_fuvb]['flux'].flatten()
# plot segment A
plt.plot(wave_fuva, flux_fuva)
plt.xlabel('Wavelength')
plt.ylabel('Flux')
plt.grid()
plt.show()

# %%
x1ddata = fits.getdata('lbji01nvq_x1d.fits')
# select segment A or segment B data
x1d_fuva = x1ddata['segment'] == 'FUVA'
x1d_fuvb = x1ddata['segment'] == 'FUVB'
# select the wavelength and flux columns for each segment
wave_fuva = x1ddata[x1d_fuva]['wavelength'].flatten()
flux_fuva = x1ddata[x1d_fuva]['flux'].flatten()
wave_fuvb = x1ddata[x1d_fuvb]['wavelength'].flatten()
flux_fuvb = x1ddata[x1d_fuvb]['flux'].flatten()
# plot segment A
plt.plot(wave_fuva, flux_fuva)
plt.xlabel('Wavelength')
plt.ylabel('Flux')
plt.grid()
plt.show()

# %%
x1ddata = fits.getdata('lbji01o0q_x1d.fits')
# select segment A or segment B data
x1d_fuva = x1ddata['segment'] == 'FUVA'
x1d_fuvb = x1ddata['segment'] == 'FUVB'
# select the wavelength and flux columns for each segment
wave_fuva = x1ddata[x1d_fuva]['wavelength'].flatten()
flux_fuva = x1ddata[x1d_fuva]['flux'].flatten()
wave_fuvb = x1ddata[x1d_fuvb]['wavelength'].flatten()
flux_fuvb = x1ddata[x1d_fuvb]['flux'].flatten()
# plot segment A
plt.plot(wave_fuva, flux_fuva)
plt.xlabel('Wavelength')
plt.ylabel('Flux')
plt.grid()
plt.show()
